# %%
cd ../..
# Out:
# C:\Users\thyne\Documents\GitHub\datasci-api

# %%
# %load_ext autoreload
# %autoreload 2
from dataset.Dataset import Dataset
from dataObj.dataObj import DataObj
from dataObj.Row import Row
from dataObj.Column import Column
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dataset = Dataset("data/cars.csv",schema=[{"Year":{"dataType":"date"}}])

# %%
from action.Filter import filter

# %%
dobj = DataObj(dataset,[Column("Acceleration")])
filter(dobj)
# Out:
# [<Data Obj: [Column <Acceleration,channel:,dataType:,dataModel:>, Row <Name,chevrolet chevelle malibu>] -- 27.50>,
#  <Data Obj: [Column <Acceleration,channel:,dataType:,dataModel:>, Row <Name,buick skylark 320>] -- 11.50>,
#  <Data Obj: [Column <Acceleration,channel:,dataType:,dataModel:>, Row <Name,plymouth satellite>] -- 11.00>,
#  <Data Obj: [Column <Acceleration,channel:,dataType:,dataModel:>, Row <Name,amc rebel sst>] -- 12.00>,
#  <Data Obj: [Column <Acceleration,channel:,dataType:,dataModel:>, Row <Name,ford torino>] -- 10.50>,
#  <Data Obj: [Column <Acceleration,channel:,dataType:,dataModel:>, Row <Name,ford galaxie 500>] -- 36.50>,
#  <Data Obj: [Column <Acceleration,channel:,dataType:,dataModel:>, Row <Name,chevrolet impala>] -- 47.00>,
#  <Data Obj: [Column <Acceleration,channel:,dataType:,dataModel:>, Row <Name,plymouth fury iii>] -- 35.00>,
#  <Data Obj: [Column <Acceleration,channel:,dataType:,dataModel:>, Row <Name,pontiac catalina>] -- 33.50>,
# ...

# %%
dobj = DataObj(dataset,[Column("Acceleration"), Row(fAttribute="Origin", fVal="USA")])
filter(dobj)
# Out:
# [<Data Obj: [Column <Acceleration,channel:,dataType:,dataModel:>, Row <Origin,USA>] -- 3672.60>,
#  <Data Obj: [Column <Acceleration,channel:,dataType:,dataModel:>, Row <Origin,Japan>] -- 1277.60>,
#  <Data Obj: [Column <Acceleration,channel:,dataType:,dataModel:>, Row <Origin,Europe>] -- 1142.00>]

# %%
dobj = DataObj(dataset,[Column("Acceleration"),Column("Horsepower"), Row(fAttribute="Origin", fVal="USA")])
filter(dobj)
# Out:
# [<Data Obj: [Column <Acceleration,channel:,dataType:,dataModel:>, Column <Horsepower,channel:,dataType:,dataModel:>, Row <Origin,USA>] -- -0.72>,
#  <Data Obj: [Column <Acceleration,channel:,dataType:,dataModel:>, Column <Horsepower,channel:,dataType:,dataModel:>, Row <Origin,Japan>] -- -0.72>,
#  <Data Obj: [Column <Acceleration,channel:,dataType:,dataModel:>, Column <Horsepower,channel:,dataType:,dataModel:>, Row <Origin,Europe>] -- -0.54>]

# %%
dobj = DataObj(dataset,[Column("Acceleration"), Column("Horsepower"), Row(fAttribute="Origin",fVal="USA"), Row(fAttribute="Brand",fVal="honda")])
filter(dobj)
# Out:
# [<Data Obj: [Column <Acceleration,channel:,dataType:,dataModel:>, Column <Horsepower,channel:,dataType:,dataModel:>, Row <Origin,USA>] -- -0.72>,
#  <Data Obj: [Column <Acceleration,channel:,dataType:,dataModel:>, Column <Horsepower,channel:,dataType:,dataModel:>, Row <Origin,Japan>] -- -0.72>,
#  <Data Obj: [Column <Acceleration,channel:,dataType:,dataModel:>, Column <Horsepower,channel:,dataType:,dataModel:>, Row <Origin,Europe>] -- -0.54>,
#  <Data Obj: [Column <Acceleration,channel:,dataType:,dataModel:>, Column <Horsepower,channel:,dataType:,dataModel:>, Row <Brand,chevrolet>] -- -0.81>,
#  <Data Obj: [Column <Acceleration,channel:,dataType:,dataModel:>, Column <Horsepower,channel:,dataType:,dataModel:>, Row <Brand,buick>] -- -0.79>,
#  <Data Obj: [Column <Acceleration,channel:,dataType:,dataModel:>, Column <Horsepower,channel:,dataType:,dataModel:>, Row <Brand,plymouth>] -- -0.67>,
# ...
