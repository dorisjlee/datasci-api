# %%
# cd /Users/jaewookim/Research/datasci-api

# %%
cd ../
# Out:
# /Users/dorislee/Desktop/Research/vizdatasci/datasci-api

# %%
import pandas as pd

# %%
# %load_ext autoreload
# %autoreload 2
from dataset.Dataset import Dataset
from dataObj.dataObj import DataObj

# %%
from dataObj.Column import Column
from dataObj.Row import Row
from search.enumeration import Enumeration

# %%
dataset = Dataset("data/cars.csv")

# %%
enumeration = Enumeration(xAttributes=["Acceleration","Horsepower"],yAttributes=["MilesPerGal"])

enumeration.GenerateDataObjCollection(dataset)

collection = enumeration.getDataObjCollection()

# %%
collection
# Out:
# <Data Obj Collection: [<Data Obj: <Dataset Obj: data/cars.csv> -- [Column <Acceleration>, Column <MilesPerGal>]>, <Data Obj: <Dataset Obj: data/cars.csv> -- [Column <Horsepower>, Column <MilesPerGal>]>]>

# %%
displays = collection.display()

# %%
displays[0]
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
displays[1]
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
dataset = Dataset("data/cars.csv",schema=[{'Year': {'dataType': 'date'}}])

enumeration = Enumeration(xAttributes=["Year"],yAttributes=["MilesPerGal","Acceleration","Horsepower"])
enumeration.GenerateDataObjCollection(dataset)
collection = enumeration.getDataObjCollection()
displays = collection.display()

# %%
displays[0]
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
displays[1]
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
displays[2]
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html
